# %% [markdown]
# <a href="https://colab.research.google.com/github/keremSU/skills-introduction-to-github/blob/main/wasd_grid_moving16_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import os
from IPython.display import clear_output
def ekrani_temizle():
    os.system('cls' if os.name == 'nt' else 'clear')
x=9
sagsol= 8
updown = 8
if x==9:
  with open("Doc2.txt","w") as f:
    pass

while (sagsol>=0 and sagsol<=16) and (updown<=16 and updown>=0):
 with open("Doc2.txt","a+") as f:
      inp =input("Yön gir (w/a/s/d): ")

      f.write(inp)
      f.seek(0)
      icerik = f.read()
      def widyaz():
        wid =[]
        for i in range(16):
            satir = []
            for j in range(16):
              satir.append(" ")
            satir.append("\n")
            wid.append(satir)
        size1 = len(wid)
        print(updown,sagsol)
        wid[sagsol].pop(updown)
        wid[sagsol].insert(updown,"O")
        print(updown,sagsol,icerik)
        for i in range(size1) :
            print(wid[i])
        return

      for a in icerik:
        checker = 0
        if a=="a":
          sagsol-=1
          checker-=1
        if a=="d":
            sagsol+=1
            checker-=1
        if a=="w":
            updown+=1
            checker-=1
        if a=="s":
            updown-=1
            checker-=1
      ekrani_temizle()
      widyaz()

      with open("Doc2.txt", "w") as f:
        pass
      time.sleep(2)
      clear_output(wait=True)
print("aferin")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3664149388.py in <cell line: 0>()
#      13 while (sagsol>=0 and sagsol<=16) and (updown<=16 and updown>=0):
#      14  with open("Doc2.txt","a+") as f:
# ---> 15       inp =input("Yön gir (w/a/s/d): ")
#      16
#      17       f.write(inp)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
